# %% [markdown]
# Nama : Izzar Suly Nashrudin <br>
# NIM : 230601110010

# %% [markdown]
# # Studi Kasus
# - Problem: Palindrome Check
# - Deskripsi:
# > Anda diminta untuk menentukan apakah sebuah string merupakan palindrom atau bukan. Sebuah string dikatakan palindrom jika string tersebut dapat dibaca sama baik dari depan maupun dari belakang.
# - Format Masukan:
# > Sebuah string yang terdiri dari karakter-karakter alfanumerik (huruf besar dan kecil tidak sensitif) dan/atau angka. Panjang string tidak melebihi 100.
# - Format Keluaran:
# > Sebuah baris berisi "YES" jika string merupakan palindrom, dan "NO" jika bukan palindrom.
#
# - Contoh Masukan:
# `madam`
# - Contoh Keluaran:
# `YES`
# - Penjelasan:
# > Pada contoh masukan, string "madam" dapat dibaca sama baik dari depan maupun dari belakang, sehingga merupakan palindrom.

# %% [markdown]
# # Implementasi Kode

# %%
def PalindromeCheck(string):
  i = 0
  j = len(string) - 1
  while i < j:
    if string[i] != string[j]:
      return print("NO")
    i += 1
    j -= 1
  return print("YES")

# %% [markdown]
# Contoh Inputan & Keluaran

# %%
x = "madam"
y = "kasur"
PalindromeCheck(x)
PalindromeCheck(y)
# Out:
# YES
# NO

# %% [markdown]
# # Menggunakan *Recursive Function*

# %%
def RecPalindromeCheck(string, i = 0, j = None ):
  if j == None:
    j = len(string) - 1
  if i >= j:
    return print("YES")
  if string[i] != string[j]:
    return print("NO")
  return RecPalindromeCheck(string, i + 1, j - 1)

# %% [markdown]
# Contoh Inputan & Keluaran

# %%
a = "madam"
b = "kasur"
RecPalindromeCheck(a)
RecPalindromeCheck(b)
# Out:
# YES
# NO
